# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_df = pd.read_csv('../output_data/Cities.csv')
city_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)
 
# Store latitude and longitude in locations
locations = city_df[["Lat", "Lng"]]

# Fill NaN values and convert to float
humidity = city_df["Humidity"]

# Plot Heatmap
fig = gmaps.Map()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity)

# Add layer
fig.add_layer(heat_layer)

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_city_data_df = city_df.loc[city_df['Max Temp'] < 80, :]
ideal_city_data_df = city_df.loc[city_df['Max Temp'] > 70, :]
ideal_city_data_df = city_df.loc[city_df['Wind Speed'] < 10, :]
ideal_city_data_df = city_df.loc[city_df['Cloudiness'] == 0, :]
ideal_city_data_df.head()
# Out:
#     City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 3         3     zhuhai           0      CN  1558378755        39  40.71
# 6         6   flinders           0      AU  1558378755        62 -34.58
# 7         7      opuwo           0     NaN  1558378523        23 -18.06
# 11       11     castro           0      CL  1558378756        70 -42.48
# 13       13  saskylakh           0      RU  1558378757        91  71.97
#
#        Lng  Max Temp  Wind Speed
# 3   112.04     44.60        4.47
# 6   150.85     60.01       11.41
# 7    13.84     72.06        5.44
# 11  -73.76     48.20        9.17
# 13  114.09      4.92        2.26

# %%
hotel_df = ideal_city_data_df
ideal_city_data_df.head()
# Out:
#     City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 3         3     zhuhai           0      CN  1558378755        39  40.71
# 6         6   flinders           0      AU  1558378755        62 -34.58
# 7         7      opuwo           0     NaN  1558378523        23 -18.06
# 11       11     castro           0      CL  1558378756        70 -42.48
# 13       13  saskylakh           0      RU  1558378757        91  71.97
#
#        Lng  Max Temp  Wind Speed
# 3   112.04     44.60        4.47
# 6   150.85     60.01       11.41
# 7    13.84     72.06        5.44
# 11  -73.76     48.20        9.17
# 13  114.09      4.92        2.26

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# create hotel_df with hotel name column
hotel_df = pd.DataFrame(ideal_city_data_df, columns=['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Hotel Name'])
hotel_df
# Out:
#                  City Country    Lat     Lng  Max Temp  Hotel Name
# 3              zhuhai      CN  40.71  112.04     44.60         NaN
# 6            flinders      AU -34.58  150.85     60.01         NaN
# 7               opuwo     NaN -18.06   13.84     72.06         NaN
# 11             castro      CL -42.48  -73.76     48.20         NaN
# 13          saskylakh      RU  71.97  114.09      4.92         NaN
# ..                ...     ...    ...     ...       ...         ...
# 527          tomatlan      MX  19.93 -105.25     84.66         NaN
# 533           hakkari      FI  61.34   23.75     69.80         NaN
# 538  la seyne-sur-mer      FR  43.10    5.88     69.01         NaN
# 543            yabrud      SY  33.97   36.66     80.60         NaN
# 545           veraval      FR  49.65    0.71     61.00         NaN
#
# [76 rows x 6 columns]

# %%
# params dictionary to update each iteration
params = {
    "radius": 5000,
    "types": "lodging",
    "keyword": "Hotel",
    "key": g_key
}

# Use the lat/lng to identify airports
for index, row in hotel_df.iterrows():
    # get lat, lng from hotel_df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "Hotel" with lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    
#print the name_address url, avoid doing for public github repos in order to avoid exposing key
    print(name_address.url)

    # convert to json
    name_address = name_address.json()
    print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
        hotel_df.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        hotel_df.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
hotel_df.info()
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=40.71%2C112.04
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-34.58%2C150.85
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-18.06%2C13.84
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-42.48%2C-73.76
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=71.97%2C114.09
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=27.13%2C81.7
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-22.45%2C18.97
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=36.09%2C120.35
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=59.7%2C150.17
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=58.61%2C5.65
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-13.71%2C-76.2
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=55.31%2C82.74
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-20.63%2C-46.0
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-23.53%2C148.16
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-30.17%2C-50.22
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-34.53%2C20.04
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-20.56%2C164.28
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-22.97%2C-42.02
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-5.09%2C-81.11
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-20.3%2C44.28
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=15.34%2C74.49
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=30.43%2C103.62
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=26.02%2C82.92
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-45.87%2C-67.48
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=63.87%2C11.3
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=35.17%2C-2.93
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=70.62%2C147.9
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=67.67%2C53.09
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-20.31%2C118.58
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-51.62%2C-69.22
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-20.73%2C139.49
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=68.38%2C17.6
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=65.44%2C52.15
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=48.94%2C2.36
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=25.26%2C63.48
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-41.87%2C-73.83
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=69.38%2C178.42
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=64.22%2C27.73
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=42.84%2C93.51
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-31.59%2C28.78
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=52.21%2C104.21
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-45.58%2C-72.07
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=22.92%2C96.51
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=61.69%2C27.27
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=39.73%2C98.49
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=72.79%2C-56.15
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=46.68%2C113.28
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=13.18%2C-16.76
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-16.38%2C-71.56
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-21.05%2C31.67
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=67.67%2C12.69
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=40.09%2C113.3
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-35.36%2C150.48
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-27.78%2C24.69
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=43.21%2C-8.69
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=39.94%2C119.59
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-15.19%2C12.15
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=25.33%2C56.02
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=20.71%2C70.98
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=35.47%2C44.4
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=62.78%2C148.15
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-39.64%2C176.84
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=47.91%2C18.5
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-39.94%2C176.59
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=32.86%2C59.22
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-22.12%2C14.28
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-24.87%2C152.35
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=45.76%2C106.27
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-22.28%2C166.46
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=-21.13%2C-56.49
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=55.43%2C-116.48
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=19.93%2C-105.25
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=61.34%2C23.75
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=43.1%2C5.88
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=33.97%2C36.66
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&types=lodging&keyword=Hotel&key=AIzaSyACgMC0NdRErNVkt-7y-dlrlW6XgPCQTAw&location=49.65%2C0.71
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "html_attributions": [],
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# Missing field/result... skipping.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 3 to 545
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        76 non-null     object
#  1   Country     73 non-null     object
#  2   Lat         76 non-null     float64
#  3   Lng         76 non-null     float64
#  4   Max Temp    76 non-null     float64
#  5   Hotel Name  0 non-null      float64
# dtypes: float64(4), object(2)
# memory usage: 4.2+ KB

# %%
target_search = "Hotel"
target_radius = 5000
target_type = "lodging"

idx = 0
for index, row in hotel_df.iterrows():
    # set up a parameters dictionary
    params = {
        "location": f"{row['Lat']}, {row['Lng']}",
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)
    response_json = response.json()
    results = response_json['results']
    if len(results) > 0:
        name = response_json['results'][0]['name']
        hotel_df.iloc[idx, -1] = name
    idx = idx + 1

narrowed_city_df = hotel_df

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Display figure
fig
